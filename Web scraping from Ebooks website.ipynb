# %%
import requests
import pandas as pd
url = "https://www.ebooks.com/api/search/bisac/?CountryCode=IN&bisacId=5204"
headers = {
    "sec-ch-ua": "\"Not)A;Brand\";v=\"99\", \"Brave\";v=\"127\", \"Chromium\";v=\"127\"",
    "Content-Type": "application/json",
    "Referer": "https://www.ebooks.com/en-in/category/computers/5204/",
    "sec-ch-ua-mobile": "?0",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36",
    "sec-ch-ua-platform": "\"Windows\""
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"search_term":null,"start_record":1,"total_results":60517,"books":[{"id":95729334,"book_url":"/en-in/book/95729334/designing-data-intensive-applications/martin-kleppmann/","image_url":"https://image.ebooks.com/cover/95729334.jpg?width=97&height=150&quality=85","image_alt_tag":"Designing Data-Intensive Applications: The Big Ideas Behind Reliable, Scalable, and Maintainable Systems","src_set":" https://image.ebooks.com/cover/95729334.jpg?width=97&height=150&quality=85 1x,  https://image.ebooks.com/cover/95729334.jpg?width=194&height=300&quality=85 2x,  https://image.ebooks.com/cover/95729334.jpg?width=291&height=450&quality=85 3x,  https://image.ebooks.com/cover/95729334.jpg?width=388&height=600&quality=85 4x","image_width":97,"image_height":150,"title":"Designing Data-Intensive Applications","edition":"","subtitle":"The Big Ideas Behind Reliable, Scalable, and Maintainable Systems","authors":[{"name":"Martin Kleppmann","normalised_name":"Kleppmann, Martin","landing_page":"/en-in/auth
# ...

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'search_term': None,
#  'start_record': 1,
#  'total_results': 60517,
#  'books': [{'id': 95729334,
#    'book_url': '/en-in/book/95729334/designing-data-intensive-applications/martin-kleppmann/',
#    'image_url': 'https://image.ebooks.com/cover/95729334.jpg?width=97&height=150&quality=85',
#    'image_alt_tag': 'Designing Data-Intensive Applications: The Big Ideas Behind Reliable, Scalable, and Maintainable Systems',
#    'src_set': ' https://image.ebooks.com/cover/95729334.jpg?width=97&height=150&quality=85 1x,  https://image.ebooks.com/cover/95729334.jpg?width=194&height=300&quality=85 2x,  https://image.ebooks.com/cover/95729334.jpg?width=291&height=450&quality=85 3x,  https://image.ebooks.com/cover/95729334.jpg?width=388&height=600&quality=85 4x',
#    'image_width': 97,
#    'image_height': 150,
#    'title': 'Designing Data-Intensive Applications',
#    'edition': '',
#    'subtitle': 'The Big Ideas Behind Reliable, Scalable, and Maintainable Systems',
# ...

# %%
#title
#subtitle
#author
#publication date
#publisher
#price
response.json()['books']
# Out:
# [{'id': 95729334,
#   'book_url': '/en-in/book/95729334/designing-data-intensive-applications/martin-kleppmann/',
#   'image_url': 'https://image.ebooks.com/cover/95729334.jpg?width=97&height=150&quality=85',
#   'image_alt_tag': 'Designing Data-Intensive Applications: The Big Ideas Behind Reliable, Scalable, and Maintainable Systems',
#   'src_set': ' https://image.ebooks.com/cover/95729334.jpg?width=97&height=150&quality=85 1x,  https://image.ebooks.com/cover/95729334.jpg?width=194&height=300&quality=85 2x,  https://image.ebooks.com/cover/95729334.jpg?width=291&height=450&quality=85 3x,  https://image.ebooks.com/cover/95729334.jpg?width=388&height=600&quality=85 4x',
#   'image_width': 97,
#   'image_height': 150,
#   'title': 'Designing Data-Intensive Applications',
#   'edition': '',
#   'subtitle': 'The Big Ideas Behind Reliable, Scalable, and Maintainable Systems',
#   'authors': [{'name': 'Martin Kleppmann',
#     'normalised_name': 'Kleppmann, Martin',
# ...

# %%
len(response.json()['books'])
# Out:
# 10

# %%
result_json = response.json()['books']

# %%
#title
result_json[0]['title']
# Out:
# 'Designing Data-Intensive Applications'

# %%
#subtitle
result_json[0]['subtitle']
# Out:
# 'The Big Ideas Behind Reliable, Scalable, and Maintainable Systems'

# %%
#authors
result_json[0]['authors']
# Out:
# [{'name': 'Martin Kleppmann',
#   'normalised_name': 'Kleppmann, Martin',
#   'landing_page': '/en-in/author/martin-kleppmann/1321307/',
#   'precedence': 0,
#   'author_type_short': ''}]

# %%
#publisher
result_json[0]['publisher']
# Out:
# "O'Reilly Media"

# %%
#price
result_json[0]['price_number']
# Out:
# 53.5395

# %%
#publication_year
result_json[0]['publication_year']
# Out:
# '2017'

# %%
title = []
subtitle = []
author = []
publisher =  []
publication_year = []
price = []

for result in result_json:
     title.append(result['title'])
     subtitle.append(result['subtitle'])
     author.append(result['authors'][0]['name'])
     publisher.append(result['publisher'])
     publication_year.append(result['publication_year'])
     price.append(result['price'])

# %%
price
# Out:
# ['US$53.54',
#  'US$59.84',
#  'US$59.84',
#  'US$35.69',
#  'US$71.39',
#  'US$62.99',
#  'US$80.84',
#  'US$35.69',
#  'US$71.39',
#  'US$62.99']

# %%
books_df = pd.DataFrame({'Title':title,'Subtitle':subtitle,'Author':author,'Publisher':publisher,'Publication Year':publication_year,'Price':price})

# %%
books_df
# Out:
#                                                Title  \
# 0              Designing Data-Intensive Applications
# 1                         Web Accessibility Cookbook
# 2                                        Learning Go
# 3                          The Staff Engineer's Path
# 4               Prompt Engineering for Generative AI
# 5           Software Engineering for Data Scientists
# 6  Hands-On Machine Learning with Scikit-Learn, K...
# 7                                        Tidy First?
# 8                             Building Microservices
# 9                                C# 12 in a Nutshell
#
#                                             Subtitle            Author  \
# 0  The Big Ideas Behind Reliable, Scalable, and M...  Martin Kleppmann
# 1                                                     Manuel Matuzovic
# 2                                                           Jon Bodner
# 3                                                         Tanya Reilly
# ...

# %%
books_df.to_csv('Books.csv',index=False)
