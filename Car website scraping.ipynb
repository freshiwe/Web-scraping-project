# %% [markdown]
# #### Step 1 - Imports

# %%
import requests
import pandas as pd

# %% [markdown]
# #### Step 2 - CURL

# %%
headers = {
    'authority': 'www.autolist.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^94^\\^, ^\\^Google',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'x-autolist-session-guid': 'c9fb9ffb-2c06-4468-a3d0-c26290c6994f',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4590.0 Safari/537.36',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzk0LjAuNDU5MC4wIFNhZmFyaS81MzcuMzYifQ==; client_guid_timestamp=1602952f-d1bf-4936-82e3-cbdedfa11d2d.1627825394925; scavenger-a493=...; _sp_ses.8ca5=*; _gid=GA1.2.96049973.1627825395; _fbp=fb.1.1627825395573.409117512; __gads=ID=c459f8bf6d0987dd:T=1627825394:S=ALNI_MaW1epD3HNJsvJQTCnPWSJCcOdE_w; AMP_TOKEN=^%^24NOT_FOUND; sp-nuid=e4461948-a1a2-45a1-88f8-45c2889d9576; _gcl_au=1.1.519751617.1627825557; _ga_152345333=GS1.1.1627825395.1.1.1627828426.0; _ga=GA1.2.2118379867.1627825395; cto_bundle=WV1etl8zMUc1cGt6WnZNSEZMYWhwNnJjUXpTYzQxVzZ6QzM5VE1tWXZFcjQ3ZWhrNTlETG1CemlUdmNFYUtIbXdCQTNFelJmY3h6QXA0SlVIZml0WVg2OWQxZlBPMmRqbExXNU9XZTM0V0VaR09tbHBvJTJGdERCb21zZUVKJTJCTG1vVzlDV0w2VjA0bDklMkJnRjdrMmZPUExmJTJGY0l6USUzRCUzRA; _gat=1; _sp_id.8ca5=d3d3f60d-371c-4289-92fe-1c6f66b4979f.1627825395.1.1627828912.1627825395.8bc1e545-8ca1-448e-b1ba-ec8d2c359ada',
    'if-none-match': 'W/^\\^c6f72fa4ef059e03ea0309ebd57c197d^\\^',
}

params = (
    ('make', 'Tesla'),
    ('location', 'San^%^20Francisco,^%^20CA'),
    ('latitude', '37.7749295'),
    ('longitude', '-122.4194155'),
    ('radius', '50'),
    ('page', '1'),
)

response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)

# %% [markdown]
# #### Step 3 - Check Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# #### Step 4 - Create Json Object

# %%
results_json = response.json()

# %%
results_json
# Out:
# {'total_results_count': 420,
#  'make_model_name': 'Tesla',
#  'trims': [],
#  'ad_info': {'ad_unit': '/19485787/AutoList.com/Search_Results_Page/Tesla',
#   'make': 'Tesla',
#   'model': None,
#   'page_type': 'srp',
#   'cpo': False,
#   'body_style': None,
#   'year': 2025,
#   'age_type': 'new',
#   'app': 'web',
#   'seller_id': None,
#   'content_url': 'https://www.autolist.com/listings#latitude=37.7749295&location=San%5E%25%5E20Francisco%2C%5E%25%5E20CA&longitude=-122.4194155&make=Tesla&page=1&radius=50'},
#  'search_results': [{'available_nationwide': False,
#    'created_at': 2024,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA1NF145109',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA1NF145109',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 290756837,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/08/03/06/51/2022_tesla_model_3-pic-534334418404718159-1024x768.jpeg',
#    'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/08/03/06/51/2022_tesla_model_3-pic-534334418404718159-1024x768.jpeg?io=true&width=320&format=jpeg',
#    'lat': 37.6541,
#    'lon': -122.07,
#    'year': 2022,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$23,998',
#    'price_unformatted': 23998,
#    'mileage': '79,973 Miles',
#    'mileage_unformatted': 79973,
#    'city': 'Hayward',
#    'state': 'CA',
#    'distance_from_origin': 20,
#    'dealer_name': 'Hayward Kia',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJ3E1EA1NF145109',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '388478378',
#     'remote_dealer_id': '437130',
#     'dealer_name': None,
#     'remote_sku': '18843',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'Base',
#    'provider_id': 199,
#    'provider_group_id': 228,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 2024,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJYGDEE0MF284876',
#    'vdp_url': '/tesla-model+y#vin=5YJYGDEE0MF284876',
#    'clickoff_url': 'https://www.lithia.com/catcher.esl?vin=5YJYGDEE0MF284876&utm_source=autolist&utm_medium=referral&utm_campaign=vdp_deep_link',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 294416627,
#    'primary_photo_url': 'https://cdn.max.auto/l_108742:645e74b6d19b6227d8295aa5/t_center_overlay/t_hres/108742/5YJYGDEE0MF284876/66bec2194c3b13ce20eac60c.jpg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--U4zk8W6q--/c_fill,f_auto,q_auto,w_320/https://cdn.max.auto/l_108742:645e74b6d19b6227d8295aa5/t_center_overlay/t_hres/108742/5YJYGDEE0MF284876/66bec2194c3b13ce20eac60c.jpg',
#    'lat': 37.771,
#    'lon': -122.417,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model Y',
#    'model_id': 2357,
#    'display_color': '',
#    'price': '$32,998',
#    'price_unformatted': 32998,
#    'mileage': '32,034 Miles',
#    'mileage_unformatted': 32034,
#    'city': 'San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 0,
#    'dealer_name': 'BMW Of San Francisco',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJYGDEE0MF284876',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '393017681',
#     'remote_dealer_id': '60230',
#     'dealer_name': 'BMW of San Francisco',
#     'remote_sku': 'MF284876T',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'bm_wof_san_francisco',
#     'dealer_uuid': '4d589c33-ae35-4ccc-ab23-edbbda0a2b8b',
#     'dealer_group_unique_name': 'lithia_cargurus',
#     'dealer_group_uuid': 'c0fa20c8-42ae-44e3-a134-36b48b15907a'},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 230,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 2024,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB5MF879582',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB5MF879582',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 294499072,
#    'primary_photo_url': 'https://content.homenetiol.com/2000096/2063606/640x480/8735f1b4039d4b14aad99537c5a4c763.jpg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--2iro2oFT--/c_fill,f_auto,q_auto,w_320/https://content.homenetiol.com/2000096/2063606/640x480/8735f1b4039d4b14aad99537c5a4c763.jpg',
#    'lat': 38.2428,
#    'lon': -122.081,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$28,287',
#    'price_unformatted': 28287,
#    'mileage': '37,482 Miles',
#    'mileage_unformatted': 37482,
#    'city': 'Fairfield',
#    'state': 'CA',
#    'distance_from_origin': 37,
#    'dealer_name': 'Audi Napa Valley',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJ3E1EB5MF879582',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '393141147',
#     'remote_dealer_id': '454058',
#     'dealer_name': None,
#     'remote_sku': '24AC1017',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 228,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 2024,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA5JF155121',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA5JF155121',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 294257965,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/08/09/01/02/2018_tesla_model_3-pic-3069026681955448563-1024x768.jpeg',
#    'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/08/09/01/02/2018_tesla_model_3-pic-3069026681955448563-1024x768.jpeg?io=true&width=320&format=jpeg',
#    'lat': 37.4503,
#    'lon': -122.119,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$24,750',
#    'price_unformatted': 24750,
#    'mileage': '26,609 Miles',
#    'mileage_unformatted': 26609,
#    'city': 'Palo Alto',
#    'state': 'CA',
#    'distance_from_origin': 27,
#    'dealer_name': 'Audi Palo Alto',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJ3E1EA5JF155121',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '392839796',
#     'remote_dealer_id': '63777',
#     'dealer_name': None,
#     'remote_sku': 'F155121P',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'Mid Range',
#    'provider_id': 199,
#    'provider_group_id': 228,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 2024,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA7NF358971',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA7NF358971',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 290480126,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/07/11/08/22/2022_tesla_model_3-pic-3548005152098123655-1024x768.jpeg',
#    'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/07/11/08/22/2022_tesla_model_3-pic-3548005152098123655-1024x768.jpeg?io=true&width=320&format=jpeg',
#    'lat': 37.6745,
#    'lon': -122.46,
#    'year': 2022,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$30,752',
#    'price_unformatted': 30752,
#    'mileage': '18,740 Miles',
#    'mileage_unformatted': 18740,
#    'city': 'Colma',
#    'state': 'CA',
#    'distance_from_origin': 7,
#    'dealer_name': 'Serramonte Subaru Volkswagen',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJ3E1EA7NF358971',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '388153872',
#     'remote_dealer_id': '387409',
#     'dealer_name': None,
#     'remote_sku': 'D3655K',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'Base',
#    'provider_id': 199,
#    'provider_group_id': 228,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 2024,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA7KF436077',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA7KF436077',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 293361866,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/07/25/19/04/2019_tesla_model_3-pic-3386047696034576055-1024x768.jpeg',
#    'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/07/25/19/04/2019_tesla_model_3-pic-3386047696034576055-1024x768.jpeg?io=true&width=320&format=jpeg',
#    'lat': 37.2757,
#    'lon': -121.875,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$21,991',
#    'price_unformatted': 21991,
#    'mileage': '80,514 Miles',
#    'mileage_unformatted': 80514,
#    'city': 'San Jose',
#    'state': 'CA',
#    'distance_from_origin': 45,
#    'dealer_name': 'Capitol Hyundai',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJ3E1EA7KF436077',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '391711772',
#     'remote_dealer_id': '305500',
#     'dealer_name': None,
#     'remote_sku': 'UH9217',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'Standard Range Plus',
#    'provider_id': 199,
#    'provider_group_id': 228,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 2024,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJSA1E23GF132820',
#    'vdp_url': '/tesla-model+s#vin=5YJSA1E23GF132820',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 291242912,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/08/13/14/02/2016_tesla_model_s-pic-2040808722164466808-1024x768.jpeg',
#    'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/08/13/14/02/2016_tesla_model_s-pic-2040808722164466808-1024x768.jpeg?io=true&width=320&format=jpeg',
#    'lat': 37.6745,
#    'lon': -122.46,
#    'year': 2016,
#    'make': 'Tesla',
#    'model': 'Model S',
#    'model_id': 2006,
#    'display_color': '',
#    'price': '$33,652',
#    'price_unformatted': 33652,
#    'mileage': '46,366 Miles',
#    'mileage_unformatted': 46366,
#    'city': 'Colma',
#    'state': 'CA',
#    'distance_from_origin': 7,
#    'dealer_name': 'Serramonte Subaru Volkswagen',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJSA1E23GF132820',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '388987645',
#     'remote_dealer_id': '387409',
#     'dealer_name': None,
#     'remote_sku': 'D3659K',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': '60D',
#    'provider_id': 199,
#    'provider_group_id': 228,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 2024,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EAXLF806486',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EAXLF806486',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 294332642,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/08/13/08/31/2020_tesla_model_3-pic-3828041420647301379-1024x768.jpeg',
#    'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/08/13/08/31/2020_tesla_model_3-pic-3828041420647301379-1024x768.jpeg?io=true&width=320&format=jpeg',
#    'lat': 38.2428,
#    'lon': -122.081,
#    'year': 2020,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$24,987',
#    'price_unformatted': 24987,
#    'mileage': '51,057 Miles',
#    'mileage_unformatted': 51057,
#    'city': 'Fairfield',
#    'state': 'CA',
#    'distance_from_origin': 37,
#    'dealer_name': 'Audi Napa Valley',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJ3E1EAXLF806486',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '392940127',
#     'remote_dealer_id': '454058',
#     'dealer_name': None,
#     'remote_sku': '24A1069A',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'Standard Range',
#    'provider_id': 199,
#    'provider_group_id': 228,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 2024,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA8KF425069',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA8KF425069',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 291440722,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/07/14/16/18/2019_tesla_model_3-pic-2182914609872819584-1024x768.jpeg',
#    'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/07/14/16/18/2019_tesla_model_3-pic-2182914609872819584-1024x768.jpeg?io=true&width=320&format=jpeg',
#    'lat': 37.4953,
#    'lon': -122.227,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$24,777',
#    'price_unformatted': 24777,
#    'mileage': '46,312 Miles',
#    'mileage_unformatted': 46312,
#    'city': 'Redwood City',
#    'state': 'CA',
#    'distance_from_origin': 22,
#    'dealer_name': 'Boardwalk Automall',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJ3E1EA8KF425069',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '389329902',
#     'remote_dealer_id': '279247',
#     'dealer_name': None,
#     'remote_sku': '3825',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'Standard Range',
#    'provider_id': 199,
#    'provider_group_id': 228,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 2024,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJXCBE23LF249507',
#    'vdp_url': '/tesla-model+x#vin=5YJXCBE23LF249507',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 294480089,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/08/13/12/19/2020_tesla_model_x-pic-4353293863249561516-1024x768.jpeg',
#    'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/08/13/12/19/2020_tesla_model_x-pic-4353293863249561516-1024x768.jpeg?io=true&width=320&format=jpeg',
#    'lat': 38.2415,
#    'lon': -122.084,
#    'year': 2020,
#    'make': 'Tesla',
#    'model': 'Model X',
#    'model_id': 2101,
#    'display_color': '',
#    'price': '$47,991',
#    'price_unformatted': 47991,
#    'mileage': '54,666 Miles',
#    'mileage_unformatted': 54666,
#    'city': 'Fairfield',
#    'state': 'CA',
#    'distance_from_origin': 37,
#    'dealer_name': 'Mercedes-Benz Fairfield',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJXCBE23LF249507',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '393092725',
#     'remote_dealer_id': '290165',
#     'dealer_name': None,
#     'remote_sku': 'AP9828E',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 228,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 2024,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJXCDE25LF304843',
#    'vdp_url': '/tesla-model+x#vin=5YJXCDE25LF304843',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 293786122,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/08/03/17/21/2020_tesla_model_x-pic-4618655770334377629-1024x768.jpeg',
#    'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/08/03/17/21/2020_tesla_model_x-pic-4618655770334377629-1024x768.jpeg?io=true&width=320&format=jpeg',
#    'lat': 37.4503,
#    'lon': -122.119,
#    'year': 2020,
#    'make': 'Tesla',
#    'model': 'Model X',
#    'model_id': 2101,
#    'display_color': '',
#    'price': '$50,495',
#    'price_unformatted': 50495,
#    'mileage': '30,114 Miles',
#    'mileage_unformatted': 30114,
#    'city': 'Palo Alto',
#    'state': 'CA',
#    'distance_from_origin': 27,
#    'dealer_name': 'Audi Palo Alto',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJXCDE25LF304843',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '392144781',
#     'remote_dealer_id': '63777',
#     'dealer_name': None,
#     'remote_sku': 'F304843T',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'Long Range Plus',
#    'provider_id': 199,
#    'provider_group_id': 228,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 2024,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA1NF144106',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA1NF144106',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 293117844,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/07/23/06/19/2022_tesla_model_3-pic-3332194210677625651-1024x768.jpeg',
#    'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/07/23/06/19/2022_tesla_model_3-pic-3332194210677625651-1024x768.jpeg?io=true&width=320&format=jpeg',
#    'lat': 38.1008,
#    'lon': -122.568,
#    'year': 2022,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$24,995',
#    'price_unformatted': 24995,
#    'mileage': '62,350 Miles',
#    'mileage_unformatted': 62350,
#    'city': 'Novato',
#    'state': 'CA',
#    'distance_from_origin': 23,
#    'dealer_name': 'Novato Chevrolet',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJ3E1EA1NF144106',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '391398321',
#     'remote_dealer_id': '47630',
#     'dealer_name': None,
#     'remote_sku': 'J5115R',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'Base',
#    'provider_id': 199,
#    'provider_group_id': 228,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 2024,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJSA1AC1DFP10729',
#    'vdp_url': '/tesla-model+s#vin=5YJSA1AC1DFP10729',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 291587782,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/07/12/08/39/2013_tesla_model_s-pic-2751454412182866641-1024x768.jpeg',
#    'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/07/12/08/39/2013_tesla_model_s-pic-2751454412182866641-1024x768.jpeg?io=true&width=320&format=jpeg',
#    'lat': 37.6541,
#    'lon': -122.07,
#    'year': 2013,
#    'make': 'Tesla',
#    'model': 'Model S',
#    'model_id': 2006,
#    'display_color': '',
#    'price': '$13,997',
#    'price_unformatted': 13997,
#    'mileage': '110,267 Miles',
#    'mileage_unformatted': 110267,
#    'city': 'Hayward',
#    'state': 'CA',
#    'distance_from_origin': 20,
#    'dealer_name': 'Hayward Kia',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJSA1AC1DFP10729',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '389511648',
#     'remote_dealer_id': '437130',
#     'dealer_name': None,
#     'remote_sku': '1506',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'Base',
#    'provider_id': 199,
#    'provider_group_id': 228,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 2024,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJYGDED8MF103644',
#    'vdp_url': '/tesla-model+y#vin=5YJYGDED8MF103644',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 293255039,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/08/02/10/58/2021_tesla_model_y-pic-156044365928527777-1024x768.jpeg',
#    'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/08/02/10/58/2021_tesla_model_y-pic-156044365928527777-1024x768.jpeg?io=true&width=320&format=jpeg',
#    'lat': 37.8793,
#    'lon': -122.515,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model Y',
#    'model_id': 2357,
#    'display_color': '',
#    'price': '$29,491',
#    'price_unformatted': 29491,
#    'mileage': '29,949 Miles',
#    'mileage_unformatted': 29949,
#    'city': 'Mill Valley',
#    'state': 'CA',
#    'distance_from_origin': 8,
#    'dealer_name': 'Porsche Marin',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJYGDED8MF103644',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '391615903',
#     'remote_dealer_id': '66417',
#     'dealer_name': None,
#     'remote_sku': 'TMF103644',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'Standard Range',
#    'provider_id': 199,
#    'provider_group_id': 228,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 2024,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJYGDEE9LF026208',
#    'vdp_url': '/tesla-model+y#vin=5YJYGDEE9LF026208',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 293625100,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/08/01/18/10/2020_tesla_model_y-pic-2971926453297781164-1024x768.jpeg',
#    'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/08/01/18/10/2020_tesla_model_y-pic-2971926453297781164-1024x768.jpeg?io=true&width=320&format=jpeg',
#    'lat': 37.6541,
#    'lon': -122.07,
#    'year': 2020,
#    'make': 'Tesla',
#    'model': 'Model Y',
#    'model_id': 2357,
#    'display_color': '',
#    'price': '$31,997',
#    'price_unformatted': 31997,
#    'mileage': '42,726 Miles',
#    'mileage_unformatted': 42726,
#    'city': 'Hayward',
#    'state': 'CA',
#    'distance_from_origin': 20,
#    'dealer_name': 'Hayward Kia',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJYGDEE9LF026208',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '392071934',
#     'remote_dealer_id': '437130',
#     'dealer_name': None,
#     'remote_sku': '19040',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 228,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 2024,
#    'recent_price_drop': True,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA7KF416556',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA7KF416556',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 293667001,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/07/30/07/59/2019_tesla_model_3-pic-2915611900019129284-1024x768.jpeg',
#    'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/07/30/07/59/2019_tesla_model_3-pic-2915611900019129284-1024x768.jpeg?io=true&width=320&format=jpeg',
#    'lat': 38.4122,
#    'lon': -122.716,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$25,450',
#    'price_unformatted': 25450,
#    'mileage': '26,829 Miles',
#    'mileage_unformatted': 26829,
#    'city': 'Santa Rosa',
#    'state': 'CA',
#    'distance_from_origin': 46,
#    'dealer_name': 'Manly Honda',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJ3E1EA7KF416556',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '392136080',
#     'remote_dealer_id': '58682',
#     'dealer_name': None,
#     'remote_sku': 'ME37439',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'Standard Range Plus',
#    'provider_id': 199,
#    'provider_group_id': 228,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': 'price_drop'},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 2024,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB5JF151482',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB5JF151482',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 294793836,
#    'primary_photo_url': 'https://vehicleimages.dealervision.com/Stevens_Creek_Chrysler_Jeep_Dodge/S5532A/S5532A_1.jpg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--9a_6u5U3--/c_fill,f_auto,q_auto,w_320/https://vehicleimages.dealervision.com/Stevens_Creek_Chrysler_Jeep_Dodge/S5532A/S5532A_1.jpg',
#    'lat': 37.3232,
#    'lon': -121.974,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$26,988',
#    'price_unformatted': 26988,
#    'mileage': '62,451 Miles',
#    'mileage_unformatted': 62451,
#    'city': 'San Jose',
#    'state': 'CA',
#    'distance_from_origin': 39,
#    'dealer_name': 'Stevens Creek Chrysler Jeep Dodge Ram',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJ3E1EB5JF151482',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '393523127',
#     'remote_dealer_id': '60382',
#     'dealer_name': None,
#     'remote_sku': 'S5532A',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 227,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': 'fresh'},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 2024,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJXCBE29GF021131',
#    'vdp_url': '/tesla-model+x#vin=5YJXCBE29GF021131',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 287261428,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/06/19/23/14/2016_tesla_model_x-pic-8594868036243504726-1024x768.jpeg',
#    'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/06/19/23/14/2016_tesla_model_x-pic-8594868036243504726-1024x768.jpeg?io=true&width=320&format=jpeg',
#    'lat': 37.5763,
#    'lon': -122.338,
#    'year': 2016,
#    'make': 'Tesla',
#    'model': 'Model X',
#    'model_id': 2101,
#    'display_color': '',
#    'price': '$30,888',
#    'price_unformatted': 30888,
#    'mileage': '86,132 Miles',
#    'mileage_unformatted': 86132,
#    'city': 'San Mateo',
#    'state': 'CA',
#    'distance_from_origin': 14,
#    'dealer_name': 'Topline Automobile',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJXCBE29GF021131',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '383833374',
#     'remote_dealer_id': '92202',
#     'dealer_name': None,
#     'remote_sku': '29993C',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': '75D',
#    'provider_id': 199,
#    'provider_group_id': 228,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 2024,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB1KF512336',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB1KF512336',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 292803254,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/08/09/03/33/2019_tesla_model_3-pic-1075545696525328088-1024x768.jpeg',
#    'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/08/09/03/33/2019_tesla_model_3-pic-1075545696525328088-1024x768.jpeg?io=true&width=320&format=jpeg',
#    'lat': 37.7117,
#    'lon': -122.164,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$29,395',
#    'price_unformatted': 29395,
#    'mileage': '34,254 Miles',
#    'mileage_unformatted': 34254,
#    'city': 'San Leandro',
#    'state': 'CA',
#    'distance_from_origin': 14,
#    'dealer_name': 'San Leandro Chrysler Dodge Jeep Ram',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJ3E1EB1KF512336',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '391043241',
#     'remote_dealer_id': '344179',
#     'dealer_name': None,
#     'remote_sku': 'SP1378A',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 228,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 2024,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJYGDEF4MF264638',
#    'vdp_url': '/tesla-model+y#vin=5YJYGDEF4MF264638',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 294260712,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/08/12/23/16/2021_tesla_model_y-pic-964052580346209450-1024x768.jpeg',
#    'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/08/12/23/16/2021_tesla_model_y-pic-964052580346209450-1024x768.jpeg?io=true&width=320&format=jpeg',
#    'lat': 37.4997,
#    'lon': -121.976,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model Y',
#    'model_id': 2357,
#    'display_color': '',
#    'price': '$36,984',
#    'price_unformatted': 36984,
#    'mileage': '15,996 Miles',
#    'mileage_unformatted': 15996,
#    'city': 'Fremont',
#    'state': 'CA',
#    'distance_from_origin': 30,
#    'dealer_name': 'Porsche Fremont',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJYGDEF4MF264638',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '392879327',
#     'remote_dealer_id': '66412',
#     'dealer_name': None,
#     'remote_sku': 'P13744',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'Performance',
#    'provider_id': 199,
#    'provider_group_id': 228,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True}],
#  'html': {'search_results': '<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/tesla-model+3#vin=5YJ3E1EA1NF145109"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' style=\'background-image: url(https://static.cargurus.com/images/forsale/2024/08/03/06/51/2022_tesla_model_3-pic-534334418404718159-1024x768.jpeg?io=true&amp;width=320&amp;format=jpeg)\' title=\'used 2022 Tesla Model 3 Base Blue 5YJ3E1EA1NF145109\'></div>\n</div>\n<div class=\'badges-container\'>\n<div class=\'outer-container\'>\n<div class=\'\' data-spot=\'0\'>\n\n</div>\n<div class=\'\' data-spot=\'1\'>\n\n</div>\n</div>\n</div>\n</div>\n<div class=\'details\'>\n<h3 class=\'AL-vehicle-primary-details -small-sm -small-xs\'>\n<div class=\'description\'>\n<div class=\'headline\'>2022 Tesla Model 3 Base</div>\n<div class=\'subtext\'>\n79,973 Miles\n<span class=\'divider\'>\n|\n</span>\n<span class=\'location\'>Hayward, CA</span>\n</div>\n</div>\n<div class=\'pricing\'>\n<div class=\'headline\'>$23,998</div>\n<div class=\'monthly-payment\' data-menu data-monthly-payment>\n<span class=\'info-link\' href=\'javascript:void(0);\'>\nest. $346/mo\n<i></i>\n</span>\n</div>\n</div>\n</h3>\n<div class=\'AL-vehicle-secondary-details -small-sm -small-xs\' data-menu>\n<div class=\'action\'>\n<span class=\'\' data-action=\'track price\'>\nTrack Price\n</span>\n<span class=\'popout-item\' data-action=\'check availability\'>\nCheck Availability\n</span>\n</div>\n</div>\n</div>\n</a>\n<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/tesla-model+y#vin=5YJYGDEE0MF284876"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' style=\'background-image: url(https://images.autolist.com/image/fetch/s--U4zk8W6q--/c_fill,f_auto,q_auto,w_320/https://cdn.max.auto/l_108742:645e74b6d19b6227d8295aa5/t_center_overlay/t_hres/108742/5YJYGDEE0MF284876/66bec2194c3b13ce20eac60c.jpg)\' title=\'used 2021 Tesla Model Y Long Range White 5YJYGDEE0MF284876\'></div>\n</div>\n<div class=\'badges-container\'>\n<div class=\'outer-container\'>\n<div class=\'\' data-spot=\'0\'>\n\n</div>\n<div class=\'\' data-spot=\'1\'>\n\n</div>\n</div>\n</div>\n</div>\n<div class=\'details\'>\n<h3 class=\'AL-vehicle-primary-details -small-sm -small-xs\'>\n<div class=\'description\'>\n<div class=\'headline\'>2021 Tesla Model Y Long Range</div>\n<div class=\'subtext\'>\n32,034 Miles\n<span class=\'divider\'>\n|\n</span>\n<span class=\'location\'>San Francisco, CA</span>\n</div>\n</div>\n<div class=\'pricing\'>\n<div class=\'headline\'>$32,998</div>\n<div class=\'monthly-payment\' data-menu data-monthly-payment>\n<span class=\'info-link\' href=\'javascript:void(0);\'>\nest. $476/mo\n<i></i>\n</span>\n</div>\n</div>\n</h3>\n<div class=\'AL-vehicle-secondary-details -small-sm -small-xs\' data-menu>\n<div class=\'action\'>\n<span class=\'\' data-action=\'track price\'>\nTrack Price\n</span>\n<span class=\'popout-item\' data-action=\'check availability\'>\nCheck Availability\n</span>\n</div>\n</div>\n</div>\n</a>\n<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/tesla-model+3#vin=5YJ3E1EB5MF879582"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' data-background-image=\'https://images.autolist.com/image/fetch/s--2iro2oFT--/c_fill,f_auto,q_auto,w_32 ...
#   'pagination': '<ul><li class="previous disabled"><a>Previous</a></li><li class="selected"><a>1</a></li><li data-page="2"><a>2</a></li><li data-page="3"><a>3</a></li><li data-page="4"><a>...</a></li><li data-page="20"><a>20</a></li><li data-page="21"><a>21</a></li><li data-page="2" class="next"><a>Next</a></li></ul>'}}

# %%
type(results_json)
# Out:
# dict

# %% [markdown]
# #### Step 5 - Output Keys

# %%
results_json.keys()
# Out:
# dict_keys(['total_results_count', 'make_model_name', 'trims', 'ad_info', 'search_results', 'html'])

# %% [markdown]
# #### Step 6 - Find your Data

# %%
# model
# mileage
# year
# dealer name
# price

# %%
results_json['search_results']
# Out:
# [{'available_nationwide': False,
#   'created_at': 2024,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA1NF145109',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA1NF145109',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 290756837,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/08/03/06/51/2022_tesla_model_3-pic-534334418404718159-1024x768.jpeg',
#   'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/08/03/06/51/2022_tesla_model_3-pic-534334418404718159-1024x768.jpeg?io=true&width=320&format=jpeg',
#   'lat': 37.6541,
#   'lon': -122.07,
#   'year': 2022,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$23,998',
#   'price_unformatted': 23998,
#   'mileage': '79,973 Miles',
#   'mileage_unformatted': 79973,
#   'city': 'Hayward',
#   'state': 'CA',
#   'distance_from_origin': 20,
#   'dealer_name': 'Hayward Kia',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EA1NF145109',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '388478378',
#    'remote_dealer_id': '437130',
#    'dealer_name': None,
#    'remote_sku': '18843',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Base',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 2024,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJYGDEE0MF284876',
#   'vdp_url': '/tesla-model+y#vin=5YJYGDEE0MF284876',
#   'clickoff_url': 'https://www.lithia.com/catcher.esl?vin=5YJYGDEE0MF284876&utm_source=autolist&utm_medium=referral&utm_campaign=vdp_deep_link',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 294416627,
#   'primary_photo_url': 'https://cdn.max.auto/l_108742:645e74b6d19b6227d8295aa5/t_center_overlay/t_hres/108742/5YJYGDEE0MF284876/66bec2194c3b13ce20eac60c.jpg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--U4zk8W6q--/c_fill,f_auto,q_auto,w_320/https://cdn.max.auto/l_108742:645e74b6d19b6227d8295aa5/t_center_overlay/t_hres/108742/5YJYGDEE0MF284876/66bec2194c3b13ce20eac60c.jpg',
#   'lat': 37.771,
#   'lon': -122.417,
#   'year': 2021,
#   'make': 'Tesla',
#   'model': 'Model Y',
#   'model_id': 2357,
#   'display_color': '',
#   'price': '$32,998',
#   'price_unformatted': 32998,
#   'mileage': '32,034 Miles',
#   'mileage_unformatted': 32034,
#   'city': 'San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 0,
#   'dealer_name': 'BMW Of San Francisco',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJYGDEE0MF284876',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '393017681',
#    'remote_dealer_id': '60230',
#    'dealer_name': 'BMW of San Francisco',
#    'remote_sku': 'MF284876T',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'bm_wof_san_francisco',
#    'dealer_uuid': '4d589c33-ae35-4ccc-ab23-edbbda0a2b8b',
#    'dealer_group_unique_name': 'lithia_cargurus',
#    'dealer_group_uuid': 'c0fa20c8-42ae-44e3-a134-36b48b15907a'},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 230,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 2024,
#   'recent_price_drop': None,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB5MF879582',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB5MF879582',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 294499072,
#   'primary_photo_url': 'https://content.homenetiol.com/2000096/2063606/640x480/8735f1b4039d4b14aad99537c5a4c763.jpg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--2iro2oFT--/c_fill,f_auto,q_auto,w_320/https://content.homenetiol.com/2000096/2063606/640x480/8735f1b4039d4b14aad99537c5a4c763.jpg',
#   'lat': 38.2428,
#   'lon': -122.081,
#   'year': 2021,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$28,287',
#   'price_unformatted': 28287,
#   'mileage': '37,482 Miles',
#   'mileage_unformatted': 37482,
#   'city': 'Fairfield',
#   'state': 'CA',
#   'distance_from_origin': 37,
#   'dealer_name': 'Audi Napa Valley',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EB5MF879582',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '393141147',
#    'remote_dealer_id': '454058',
#    'dealer_name': None,
#    'remote_sku': '24AC1017',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 2024,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA5JF155121',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA5JF155121',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 294257965,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/08/09/01/02/2018_tesla_model_3-pic-3069026681955448563-1024x768.jpeg',
#   'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/08/09/01/02/2018_tesla_model_3-pic-3069026681955448563-1024x768.jpeg?io=true&width=320&format=jpeg',
#   'lat': 37.4503,
#   'lon': -122.119,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$24,750',
#   'price_unformatted': 24750,
#   'mileage': '26,609 Miles',
#   'mileage_unformatted': 26609,
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'distance_from_origin': 27,
#   'dealer_name': 'Audi Palo Alto',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EA5JF155121',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '392839796',
#    'remote_dealer_id': '63777',
#    'dealer_name': None,
#    'remote_sku': 'F155121P',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Mid Range',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 2024,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA7NF358971',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA7NF358971',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 290480126,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/07/11/08/22/2022_tesla_model_3-pic-3548005152098123655-1024x768.jpeg',
#   'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/07/11/08/22/2022_tesla_model_3-pic-3548005152098123655-1024x768.jpeg?io=true&width=320&format=jpeg',
#   'lat': 37.6745,
#   'lon': -122.46,
#   'year': 2022,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$30,752',
#   'price_unformatted': 30752,
#   'mileage': '18,740 Miles',
#   'mileage_unformatted': 18740,
#   'city': 'Colma',
#   'state': 'CA',
#   'distance_from_origin': 7,
#   'dealer_name': 'Serramonte Subaru Volkswagen',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EA7NF358971',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '388153872',
#    'remote_dealer_id': '387409',
#    'dealer_name': None,
#    'remote_sku': 'D3655K',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Base',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 2024,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA7KF436077',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA7KF436077',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 293361866,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/07/25/19/04/2019_tesla_model_3-pic-3386047696034576055-1024x768.jpeg',
#   'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/07/25/19/04/2019_tesla_model_3-pic-3386047696034576055-1024x768.jpeg?io=true&width=320&format=jpeg',
#   'lat': 37.2757,
#   'lon': -121.875,
#   'year': 2019,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$21,991',
#   'price_unformatted': 21991,
#   'mileage': '80,514 Miles',
#   'mileage_unformatted': 80514,
#   'city': 'San Jose',
#   'state': 'CA',
#   'distance_from_origin': 45,
#   'dealer_name': 'Capitol Hyundai',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EA7KF436077',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '391711772',
#    'remote_dealer_id': '305500',
#    'dealer_name': None,
#    'remote_sku': 'UH9217',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Standard Range Plus',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 2024,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJSA1E23GF132820',
#   'vdp_url': '/tesla-model+s#vin=5YJSA1E23GF132820',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 291242912,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/08/13/14/02/2016_tesla_model_s-pic-2040808722164466808-1024x768.jpeg',
#   'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/08/13/14/02/2016_tesla_model_s-pic-2040808722164466808-1024x768.jpeg?io=true&width=320&format=jpeg',
#   'lat': 37.6745,
#   'lon': -122.46,
#   'year': 2016,
#   'make': 'Tesla',
#   'model': 'Model S',
#   'model_id': 2006,
#   'display_color': '',
#   'price': '$33,652',
#   'price_unformatted': 33652,
#   'mileage': '46,366 Miles',
#   'mileage_unformatted': 46366,
#   'city': 'Colma',
#   'state': 'CA',
#   'distance_from_origin': 7,
#   'dealer_name': 'Serramonte Subaru Volkswagen',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJSA1E23GF132820',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '388987645',
#    'remote_dealer_id': '387409',
#    'dealer_name': None,
#    'remote_sku': 'D3659K',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': '60D',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 2024,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EAXLF806486',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EAXLF806486',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 294332642,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/08/13/08/31/2020_tesla_model_3-pic-3828041420647301379-1024x768.jpeg',
#   'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/08/13/08/31/2020_tesla_model_3-pic-3828041420647301379-1024x768.jpeg?io=true&width=320&format=jpeg',
#   'lat': 38.2428,
#   'lon': -122.081,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$24,987',
#   'price_unformatted': 24987,
#   'mileage': '51,057 Miles',
#   'mileage_unformatted': 51057,
#   'city': 'Fairfield',
#   'state': 'CA',
#   'distance_from_origin': 37,
#   'dealer_name': 'Audi Napa Valley',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EAXLF806486',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '392940127',
#    'remote_dealer_id': '454058',
#    'dealer_name': None,
#    'remote_sku': '24A1069A',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Standard Range',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 2024,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA8KF425069',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA8KF425069',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 291440722,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/07/14/16/18/2019_tesla_model_3-pic-2182914609872819584-1024x768.jpeg',
#   'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/07/14/16/18/2019_tesla_model_3-pic-2182914609872819584-1024x768.jpeg?io=true&width=320&format=jpeg',
#   'lat': 37.4953,
#   'lon': -122.227,
#   'year': 2019,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$24,777',
#   'price_unformatted': 24777,
#   'mileage': '46,312 Miles',
#   'mileage_unformatted': 46312,
#   'city': 'Redwood City',
#   'state': 'CA',
#   'distance_from_origin': 22,
#   'dealer_name': 'Boardwalk Automall',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EA8KF425069',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '389329902',
#    'remote_dealer_id': '279247',
#    'dealer_name': None,
#    'remote_sku': '3825',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Standard Range',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 2024,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJXCBE23LF249507',
#   'vdp_url': '/tesla-model+x#vin=5YJXCBE23LF249507',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 294480089,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/08/13/12/19/2020_tesla_model_x-pic-4353293863249561516-1024x768.jpeg',
#   'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/08/13/12/19/2020_tesla_model_x-pic-4353293863249561516-1024x768.jpeg?io=true&width=320&format=jpeg',
#   'lat': 38.2415,
#   'lon': -122.084,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model X',
#   'model_id': 2101,
#   'display_color': '',
#   'price': '$47,991',
#   'price_unformatted': 47991,
#   'mileage': '54,666 Miles',
#   'mileage_unformatted': 54666,
#   'city': 'Fairfield',
#   'state': 'CA',
#   'distance_from_origin': 37,
#   'dealer_name': 'Mercedes-Benz Fairfield',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJXCBE23LF249507',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '393092725',
#    'remote_dealer_id': '290165',
#    'dealer_name': None,
#    'remote_sku': 'AP9828E',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 2024,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJXCDE25LF304843',
#   'vdp_url': '/tesla-model+x#vin=5YJXCDE25LF304843',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 293786122,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/08/03/17/21/2020_tesla_model_x-pic-4618655770334377629-1024x768.jpeg',
#   'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/08/03/17/21/2020_tesla_model_x-pic-4618655770334377629-1024x768.jpeg?io=true&width=320&format=jpeg',
#   'lat': 37.4503,
#   'lon': -122.119,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model X',
#   'model_id': 2101,
#   'display_color': '',
#   'price': '$50,495',
#   'price_unformatted': 50495,
#   'mileage': '30,114 Miles',
#   'mileage_unformatted': 30114,
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'distance_from_origin': 27,
#   'dealer_name': 'Audi Palo Alto',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJXCDE25LF304843',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '392144781',
#    'remote_dealer_id': '63777',
#    'dealer_name': None,
#    'remote_sku': 'F304843T',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Long Range Plus',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 2024,
#   'recent_price_drop': None,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA1NF144106',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA1NF144106',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 293117844,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/07/23/06/19/2022_tesla_model_3-pic-3332194210677625651-1024x768.jpeg',
#   'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/07/23/06/19/2022_tesla_model_3-pic-3332194210677625651-1024x768.jpeg?io=true&width=320&format=jpeg',
#   'lat': 38.1008,
#   'lon': -122.568,
#   'year': 2022,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$24,995',
#   'price_unformatted': 24995,
#   'mileage': '62,350 Miles',
#   'mileage_unformatted': 62350,
#   'city': 'Novato',
#   'state': 'CA',
#   'distance_from_origin': 23,
#   'dealer_name': 'Novato Chevrolet',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EA1NF144106',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '391398321',
#    'remote_dealer_id': '47630',
#    'dealer_name': None,
#    'remote_sku': 'J5115R',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Base',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 2024,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJSA1AC1DFP10729',
#   'vdp_url': '/tesla-model+s#vin=5YJSA1AC1DFP10729',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 291587782,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/07/12/08/39/2013_tesla_model_s-pic-2751454412182866641-1024x768.jpeg',
#   'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/07/12/08/39/2013_tesla_model_s-pic-2751454412182866641-1024x768.jpeg?io=true&width=320&format=jpeg',
#   'lat': 37.6541,
#   'lon': -122.07,
#   'year': 2013,
#   'make': 'Tesla',
#   'model': 'Model S',
#   'model_id': 2006,
#   'display_color': '',
#   'price': '$13,997',
#   'price_unformatted': 13997,
#   'mileage': '110,267 Miles',
#   'mileage_unformatted': 110267,
#   'city': 'Hayward',
#   'state': 'CA',
#   'distance_from_origin': 20,
#   'dealer_name': 'Hayward Kia',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJSA1AC1DFP10729',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '389511648',
#    'remote_dealer_id': '437130',
#    'dealer_name': None,
#    'remote_sku': '1506',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Base',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 2024,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJYGDED8MF103644',
#   'vdp_url': '/tesla-model+y#vin=5YJYGDED8MF103644',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 293255039,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/08/02/10/58/2021_tesla_model_y-pic-156044365928527777-1024x768.jpeg',
#   'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/08/02/10/58/2021_tesla_model_y-pic-156044365928527777-1024x768.jpeg?io=true&width=320&format=jpeg',
#   'lat': 37.8793,
#   'lon': -122.515,
#   'year': 2021,
#   'make': 'Tesla',
#   'model': 'Model Y',
#   'model_id': 2357,
#   'display_color': '',
#   'price': '$29,491',
#   'price_unformatted': 29491,
#   'mileage': '29,949 Miles',
#   'mileage_unformatted': 29949,
#   'city': 'Mill Valley',
#   'state': 'CA',
#   'distance_from_origin': 8,
#   'dealer_name': 'Porsche Marin',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJYGDED8MF103644',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '391615903',
#    'remote_dealer_id': '66417',
#    'dealer_name': None,
#    'remote_sku': 'TMF103644',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Standard Range',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 2024,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJYGDEE9LF026208',
#   'vdp_url': '/tesla-model+y#vin=5YJYGDEE9LF026208',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 293625100,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/08/01/18/10/2020_tesla_model_y-pic-2971926453297781164-1024x768.jpeg',
#   'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/08/01/18/10/2020_tesla_model_y-pic-2971926453297781164-1024x768.jpeg?io=true&width=320&format=jpeg',
#   'lat': 37.6541,
#   'lon': -122.07,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model Y',
#   'model_id': 2357,
#   'display_color': '',
#   'price': '$31,997',
#   'price_unformatted': 31997,
#   'mileage': '42,726 Miles',
#   'mileage_unformatted': 42726,
#   'city': 'Hayward',
#   'state': 'CA',
#   'distance_from_origin': 20,
#   'dealer_name': 'Hayward Kia',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJYGDEE9LF026208',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '392071934',
#    'remote_dealer_id': '437130',
#    'dealer_name': None,
#    'remote_sku': '19040',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 2024,
#   'recent_price_drop': True,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA7KF416556',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA7KF416556',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 293667001,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/07/30/07/59/2019_tesla_model_3-pic-2915611900019129284-1024x768.jpeg',
#   'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/07/30/07/59/2019_tesla_model_3-pic-2915611900019129284-1024x768.jpeg?io=true&width=320&format=jpeg',
#   'lat': 38.4122,
#   'lon': -122.716,
#   'year': 2019,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$25,450',
#   'price_unformatted': 25450,
#   'mileage': '26,829 Miles',
#   'mileage_unformatted': 26829,
#   'city': 'Santa Rosa',
#   'state': 'CA',
#   'distance_from_origin': 46,
#   'dealer_name': 'Manly Honda',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EA7KF416556',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '392136080',
#    'remote_dealer_id': '58682',
#    'dealer_name': None,
#    'remote_sku': 'ME37439',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Standard Range Plus',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 2024,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB5JF151482',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB5JF151482',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 294793836,
#   'primary_photo_url': 'https://vehicleimages.dealervision.com/Stevens_Creek_Chrysler_Jeep_Dodge/S5532A/S5532A_1.jpg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--9a_6u5U3--/c_fill,f_auto,q_auto,w_320/https://vehicleimages.dealervision.com/Stevens_Creek_Chrysler_Jeep_Dodge/S5532A/S5532A_1.jpg',
#   'lat': 37.3232,
#   'lon': -121.974,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$26,988',
#   'price_unformatted': 26988,
#   'mileage': '62,451 Miles',
#   'mileage_unformatted': 62451,
#   'city': 'San Jose',
#   'state': 'CA',
#   'distance_from_origin': 39,
#   'dealer_name': 'Stevens Creek Chrysler Jeep Dodge Ram',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EB5JF151482',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '393523127',
#    'remote_dealer_id': '60382',
#    'dealer_name': None,
#    'remote_sku': 'S5532A',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 227,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': 'fresh'},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 2024,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJXCBE29GF021131',
#   'vdp_url': '/tesla-model+x#vin=5YJXCBE29GF021131',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 287261428,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/06/19/23/14/2016_tesla_model_x-pic-8594868036243504726-1024x768.jpeg',
#   'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/06/19/23/14/2016_tesla_model_x-pic-8594868036243504726-1024x768.jpeg?io=true&width=320&format=jpeg',
#   'lat': 37.5763,
#   'lon': -122.338,
#   'year': 2016,
#   'make': 'Tesla',
#   'model': 'Model X',
#   'model_id': 2101,
#   'display_color': '',
#   'price': '$30,888',
#   'price_unformatted': 30888,
#   'mileage': '86,132 Miles',
#   'mileage_unformatted': 86132,
#   'city': 'San Mateo',
#   'state': 'CA',
#   'distance_from_origin': 14,
#   'dealer_name': 'Topline Automobile',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJXCBE29GF021131',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '383833374',
#    'remote_dealer_id': '92202',
#    'dealer_name': None,
#    'remote_sku': '29993C',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': '75D',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 2024,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB1KF512336',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB1KF512336',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 292803254,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/08/09/03/33/2019_tesla_model_3-pic-1075545696525328088-1024x768.jpeg',
#   'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/08/09/03/33/2019_tesla_model_3-pic-1075545696525328088-1024x768.jpeg?io=true&width=320&format=jpeg',
#   'lat': 37.7117,
#   'lon': -122.164,
#   'year': 2019,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$29,395',
#   'price_unformatted': 29395,
#   'mileage': '34,254 Miles',
#   'mileage_unformatted': 34254,
#   'city': 'San Leandro',
#   'state': 'CA',
#   'distance_from_origin': 14,
#   'dealer_name': 'San Leandro Chrysler Dodge Jeep Ram',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EB1KF512336',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '391043241',
#    'remote_dealer_id': '344179',
#    'dealer_name': None,
#    'remote_sku': 'SP1378A',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 2024,
#   'recent_price_drop': None,
#   'is_hot': False,
#   'href_target': '/listings/5YJYGDEF4MF264638',
#   'vdp_url': '/tesla-model+y#vin=5YJYGDEF4MF264638',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 294260712,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/08/12/23/16/2021_tesla_model_y-pic-964052580346209450-1024x768.jpeg',
#   'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/08/12/23/16/2021_tesla_model_y-pic-964052580346209450-1024x768.jpeg?io=true&width=320&format=jpeg',
#   'lat': 37.4997,
#   'lon': -121.976,
#   'year': 2021,
#   'make': 'Tesla',
#   'model': 'Model Y',
#   'model_id': 2357,
#   'display_color': '',
#   'price': '$36,984',
#   'price_unformatted': 36984,
#   'mileage': '15,996 Miles',
#   'mileage_unformatted': 15996,
#   'city': 'Fremont',
#   'state': 'CA',
#   'distance_from_origin': 30,
#   'dealer_name': 'Porsche Fremont',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJYGDEF4MF264638',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '392879327',
#    'remote_dealer_id': '66412',
#    'dealer_name': None,
#    'remote_sku': 'P13744',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Performance',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True}]

# %%
len(results_json['search_results'])
# Out:
# 20

# %%
result_items = results_json['search_results']

# %%
# starting point for first result
results_json['search_results'][0]
# Out:
# {'available_nationwide': False,
#  'created_at': 2024,
#  'recent_price_drop': False,
#  'is_hot': False,
#  'href_target': '/listings/5YJ3E1EA1NF145109',
#  'vdp_url': '/tesla-model+3#vin=5YJ3E1EA1NF145109',
#  'clickoff_url': '',
#  'accepts_leads': True,
#  'open_in_new_window': False,
#  'id': 290756837,
#  'primary_photo_url': 'https://static.cargurus.com/images/forsale/2024/08/03/06/51/2022_tesla_model_3-pic-534334418404718159-1024x768.jpeg',
#  'thumbnail_url_large': 'https://static.cargurus.com/images/forsale/2024/08/03/06/51/2022_tesla_model_3-pic-534334418404718159-1024x768.jpeg?io=true&width=320&format=jpeg',
#  'lat': 37.6541,
#  'lon': -122.07,
#  'year': 2022,
#  'make': 'Tesla',
#  'model': 'Model 3',
#  'model_id': 2217,
#  'display_color': '',
#  'price': '$23,998',
#  'price_unformatted': 23998,
#  'mileage': '79,973 Miles',
#  'mileage_unformatted': 79973,
#  'city': 'Hayward',
#  'state': 'CA',
#  'distance_from_origin': 20,
#  'dealer_name': 'Hayward Kia',
#  'show_message_box': None,
#  'email_opt_default': True,
#  'show_financing_checkbox': None,
#  'show_new_mileage': False,
#  'show_thankyou_page': False,
#  'show_rsrp': True,
#  'click_off': False,
#  'pre_check_thankyou': True,
#  'cpl_value': 3,
#  'partner_type': 'metasearch',
#  'vin': '5YJ3E1EA1NF145109',
#  'provider': None,
#  'provider_name': 'car_gurus',
#  'always_ask_for_zip': False,
#  'listing_id': None,
#  'time_on_market': None,
#  'total_price_change': None,
#  'relative_price_difference': None,
#  'listimate_category': None,
#  'listimate_text': None,
#  'photo_urls': [],
#  'tracking_params': {'id_from_provider': '388478378',
#   'remote_dealer_id': '437130',
#   'dealer_name': None,
#   'remote_sku': '18843',
#   'experience': 'local',
#   'rooftop_unique_name': None,
#   'rooftop_uuid': None,
#   'dealer_unique_name': None,
#   'dealer_uuid': None,
#   'dealer_group_unique_name': None,
#   'dealer_group_uuid': None},
#  'trim': 'Base',
#  'provider_id': 199,
#  'provider_group_id': 228,
#  'experience': 'local',
#  'regional': False,
#  'badges': {'position0': None, 'position1': None},
#  'quick_picks_eligible': True}

# %%
# model 
results_json['search_results'][0]['model']
# Out:
# 'Model 3'

# %%
# mileage
results_json['search_results'][0]['mileage']
# Out:
# '79,973 Miles'

# %%
# year
results_json['search_results'][0]['year']
# Out:
# 2022

# %%
# dealer name
results_json['search_results'][0]['dealer_name']
# Out:
# 'Hayward Kia'

# %%
# price
results_json['search_results'][0]['price']
# Out:
# '$23,998'

# %% [markdown]
# #### Step 7 - Put everything together - Loop through results and append data inside a list

# %%
model = []
mileage = []
year = []
dealer_name = []
price = []

for result in result_items:
    
    # model
    model.append(result['model'])
    
    # mileage
    mileage.append(result['mileage'])
    
    # year
    year.append(result['year']) 
    
    # dealer name
    dealer_name.append(result['dealer_name']) 
    
    # price
    price.append(result['price'])

# %% [markdown]
# #### Step 8 - Pandas Dataframe - Single Page

# %%
tesla_df = pd.DataFrame({'Model': model, 'Mileage':mileage, 'Year':year, 'Dealer Name': dealer_name, 'Price': price})

# %%
tesla_df
# Out:
#       Model        Mileage  Year                            Dealer Name  \
# 0   Model 3   79,973 Miles  2022                            Hayward Kia
# 1   Model Y   32,034 Miles  2021                   BMW Of San Francisco
# 2   Model 3   37,482 Miles  2021                       Audi Napa Valley
# 3   Model 3   26,609 Miles  2018                         Audi Palo Alto
# 4   Model 3   18,740 Miles  2022           Serramonte Subaru Volkswagen
# 5   Model 3   80,514 Miles  2019                        Capitol Hyundai
# 6   Model S   46,366 Miles  2016           Serramonte Subaru Volkswagen
# 7   Model 3   51,057 Miles  2020                       Audi Napa Valley
# 8   Model 3   46,312 Miles  2019                     Boardwalk Automall
# 9   Model X   54,666 Miles  2020                Mercedes-Benz Fairfield
# 10  Model X   30,114 Miles  2020                         Audi Palo Alto
# 11  Model 3   62,350 Miles  2022                       Novato Chevrolet
# 12  Model S  110,267 Miles  2013                            Hayward Kia
# 13  Model Y   29,949 Miles  2021                          Porsche Marin
# 14  Model Y   42,726 Miles  2020                            Hayward Kia
# 15  Model 3   26,829 Miles  2019                            Manly Honda
# 16  Model 3   62,451 Miles  2018  Stevens Creek Chrysler Jeep Dodge Ram
# 17  Model X   86,132 Miles  2016                     Topline Automobile
# 18  Model 3   34,254 Miles  2019    San Leandro Chrysler Dodge Jeep Ram
# 19  Model Y   15,996 Miles  2021                        Porsche Fremont
#
#       Price
# 0   $23,998
# 1   $32,998
# 2   $28,287
# 3   $24,750
# 4   $30,752
# 5   $21,991
# 6   $33,652
# 7   $24,987
# 8   $24,777
# 9   $47,991
# 10  $50,495
# 11  $24,995
# 12  $13,997
# 13  $29,491
# 14  $31,997
# 15  $25,450
# 16  $26,988
# 17  $30,888
# 18  $29,395
# 19  $36,984

# %%
tesla_df.to_excel('tesla_single_page.xlsx', index=False)

# %% [markdown]
# #### Step 9 - Scraping Multiple Pages (here: 5pages to get 100 results)

# %%
headers = {
    'authority': 'www.autolist.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^94^\\^, ^\\^Google',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'x-autolist-session-guid': 'c9fb9ffb-2c06-4468-a3d0-c26290c6994f',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4590.0 Safari/537.36',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzk0LjAuNDU5MC4wIFNhZmFyaS81MzcuMzYifQ==; client_guid_timestamp=1602952f-d1bf-4936-82e3-cbdedfa11d2d.1627825394925; scavenger-a493=...; _sp_ses.8ca5=*; _gid=GA1.2.96049973.1627825395; _fbp=fb.1.1627825395573.409117512; __gads=ID=c459f8bf6d0987dd:T=1627825394:S=ALNI_MaW1epD3HNJsvJQTCnPWSJCcOdE_w; AMP_TOKEN=^%^24NOT_FOUND; sp-nuid=e4461948-a1a2-45a1-88f8-45c2889d9576; _gcl_au=1.1.519751617.1627825557; _ga_152345333=GS1.1.1627825395.1.1.1627828426.0; _ga=GA1.2.2118379867.1627825395; cto_bundle=WV1etl8zMUc1cGt6WnZNSEZMYWhwNnJjUXpTYzQxVzZ6QzM5VE1tWXZFcjQ3ZWhrNTlETG1CemlUdmNFYUtIbXdCQTNFelJmY3h6QXA0SlVIZml0WVg2OWQxZlBPMmRqbExXNU9XZTM0V0VaR09tbHBvJTJGdERCb21zZUVKJTJCTG1vVzlDV0w2VjA0bDklMkJnRjdrMmZPUExmJTJGY0l6USUzRCUzRA; _gat=1; _sp_id.8ca5=d3d3f60d-371c-4289-92fe-1c6f66b4979f.1627825395.1.1627828912.1627825395.8bc1e545-8ca1-448e-b1ba-ec8d2c359ada',
    'if-none-match': 'W/^\\^c6f72fa4ef059e03ea0309ebd57c197d^\\^',
}


model = []
mileage = []
year = []
dealer_name = []
price = []

for i in range(1,6):

    params = (
        ('make', 'Tesla'),
        ('location', 'San^%^20Francisco,^%^20CA'),
        ('latitude', '37.7749295'),
        ('longitude', '-122.4194155'),
        ('radius', '50'),
        ('page', str(i)),
    )
    
    # response variable for the get request
    response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)
    
    # json object
    results_json = response.json()
    
    # result items (20 items for each page)
    result_items = results_json['search_results']
    
    for result in result_items:
    
        # model
        model.append(result['model'])

        # mileage
        mileage.append(result['mileage'])

        # year
        year.append(result['year']) 

        # dealer name
        dealer_name.append(result['dealer_name']) 

        # price
        price.append(result['price'])

# %%
tesla_multiple_df = pd.DataFrame({'Model': model, 'Mileage':mileage, 'Year':year, 'Dealer Name': dealer_name, 'Price': price})

# %%
tesla_multiple_df
# Out:
#       Model       Mileage  Year                   Dealer Name    Price
# 0   Model 3  79,973 Miles  2022                   Hayward Kia  $23,998
# 1   Model Y  32,034 Miles  2021          BMW Of San Francisco  $32,998
# 2   Model 3  37,482 Miles  2021              Audi Napa Valley  $28,287
# 3   Model 3  26,609 Miles  2018                Audi Palo Alto  $24,750
# 4   Model 3  18,740 Miles  2022  Serramonte Subaru Volkswagen  $30,752
# ..      ...           ...   ...                           ...      ...
# 95  Model X  31,286 Miles  2020                  Ever Cars Co  $51,999
# 96  Model Y  25,411 Miles  2023        Stevens Creek Showcase  $39,995
# 97  Model 3  62,612 Miles  2021                 Novato Toyota  $30,990
# 98  Model Y  28,405 Miles  2021             EZ Auto Sales Inc  $33,400
# 99  Model 3  39,536 Miles  2020             Dublin Volkswagen  $27,881
#
# [100 rows x 5 columns]

# %% [markdown]
# #### Step 10 - Store Results in Excel

# %%
tesla_multiple_df.to_excel('tesla_multiple_pages.xlsx', index=False)
