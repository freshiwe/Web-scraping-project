# %% [markdown]
# #### Step 1 - Imports

# %%
import requests
import pandas as pd

# %% [markdown]
# #### Step 2 - Request & CURL

# %%
headers = {
    'authority': 'www.behance.net',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^94^\\^, ^\\^Google',
    'x-newrelic-id': 'VgUFVldbGwsFU1BRDwUBVw==',
    'x-bcp': '9f68537b-3d41-4309-992b-2a16b9e83674',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4590.0 Safari/537.36',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.behance.net/search/projects?field=architecture',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'gki=^%^7B^%^22db_semaphore^%^22^%^3Afalse^%^2C^%^22native_lazy_loading^%^22^%^3Afalse^%^2C^%^22feature_hire_me_cta^%^22^%^3Afalse^%^2C^%^22search_recommended_images_with_field_factor^%^22^%^3Afalse^%^2C^%^22feature_stock_rail^%^22^%^3Afalse^%^2C^%^22feature_updated_profile_checklist^%^22^%^3Afalse^%^7D; OptanonAlertBoxClosed=2021-08-02T06:04:21.127Z; feds_privacy_consent=^{^\\^hasUserProvidedConsent^\\^:true,^\\^userHasCustomConsent^\\^:false^}; sign_up_prompt=true; OptanonChoice=1; gk_suid=67106599; bcp=9f68537b-3d41-4309-992b-2a16b9e83674; AMCVS_9E1005A551ED61CA0A490D45^%^40AdobeOrg=1; AMCV_9E1005A551ED61CA0A490D45^%^40AdobeOrg=870038026^%^7CMCMID^%^7C36890020453938104313310156140129842450^%^7CMCAAMLH-1628607112^%^7C6^%^7CMCAAMB-1628607112^%^7CRKhpRz8krg2tLO6pguXWp5olkAcUniQYPHaMWWgdJ3xzPWQmdj0y^%^7CMCOPTOUT-1628009512s^%^7CNONE^%^7CMCAID^%^7CNONE^%^7CMCCIDH^%^7C-2144737571^%^7CvVersion^%^7C5.0.0; s_cc=true; gpv=behance.net:search:projects; s_sq=^%^5B^%^5BB^%^5D^%^5D; s_ppv=^[^%^22www.behance.net/^%^22^%^2C100^%^2C0^%^2C38350.80078125^%^2C558^%^2C754^%^2C1536^%^2C864^%^2C1.25^%^2C^%^22L^%^22^]; ilo0=true; OptanonConsent=isIABGlobal=false&datestamp=Tue+Aug+03+2021+17^%^3A44^%^3A38+GMT^%^2B0200+(Central+European+Summer+Time)&version=6.9.0&consentId=a7d2e804-5724-47c2-9e08-00c34472ff73&interactionCount=3&landingPath=NotLandingPage&groups=C0001^%^3A1^%^2CC0002^%^3A1^%^2CC0003^%^3A1^%^2CC0004^%^3A1&hosts=H111^%^3A1^%^2CH363^%^3A1^%^2CH364^%^3A1^%^2CH115^%^3A1^%^2CH117^%^3A1^%^2CH118^%^3A1^%^2CH119^%^3A1^%^2CH6^%^3A1^%^2CH122^%^3A1^%^2CH123^%^3A1^%^2CH127^%^3A1^%^2CH116^%^3A1^%^2CH4^%^3A1^%^2CH5^%^3A1^%^2CH120^%^3A1^%^2CH74^%^3A1^%^2CH76^%^3A1^%^2CH113^%^3A1^%^2CH320^%^3A1^%^2CH68^%^3A1^%^2CH88^%^3A1^%^2CH13^%^3A1^%^2CH37^%^3A1^%^2CH16^%^3A1^%^2CH67^%^3A1^%^2CH22^%^3A1^%^2CH93^%^3A1^%^2CH50^%^3A1^%^2CH124^%^3A1^%^2CH125^%^3A1^%^2CH126^%^3A1^%^2CH77^%^3A1^%^2CH35^%^3A1&geolocation=DE^%^3BHH&AwaitingReconsent=false',
}

params = (
    ('content', 'projects'),
    ('field', 'architecture'),
    ('ordinal', '0'),
)

response = requests.get('https://www.behance.net/search', headers=headers, params=params)

# %% [markdown]
# #### Step 3 - Check Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# #### Step 4 - Create Json Object

# %%
results_json = response.json()

# %% [markdown]
# #### Step 5 - Output Keys

# %%
results_json.keys()
# Out:
# dict_keys(['search', 'creativeFields', 'tools', 'schools'])

# %% [markdown]
# #### Step 6 - Find your Data

# %%
# result items (total: 48)
result_items = results_json['search']['content']['projects']

# %%
# check the length
len(result_items)
# Out:
# 48

# %%
result_items[0]
# Out:
# {'id': 122475263,
#  'name': 'DOHER Studio｜Fish Migration',
#  'published_on': 1625026424,
#  'created_on': 1624950710,
#  'modified_on': 1627999233,
#  'url': 'https://www.behance.net/gallery/122475263/DOHER-StudioFish-Migration',
#  'slug': 'DOHER-StudioFish-Migration',
#  'privacy': 'public',
#  'fields': ['Photography', 'Architecture', 'Interior Design'],
#  'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/09b757122475263.Y3JvcCwxMjU1LDk4MiwxNzAsMA.jpg',
#   '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/09b757122475263.Y3JvcCwxMjU1LDk4MiwxNzAsMA.jpg',
#   '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/09b757122475263.Y3JvcCwxMjU1LDk4MiwxNzAsMA.jpg',
#   '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/09b757122475263.Y3JvcCwxMjU1LDk4MiwxNzAsMA.jpg',
#   '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/09b757122475263.Y3JvcCwxMjU1LDk4MiwxNzAsMA.jpg',
# ...

# %%
# name
# first name
# last name
# user name
# country
# views
# appreciations
# comments
# url

# %%
# name
result_items[0]['name']
# Out:
# 'DOHER Studio｜Fish Migration'

# %%
# first name
result_items[0]['owners'][0]['first_name']
# Out:
# 'Hey!'

# %%
# last name
result_items[0]['owners'][0]['last_name']
# Out:
# 'Cheese'

# %%
# username
result_items[0]['owners'][0]['username']
# Out:
# 'heycheese'

# %%
# country
result_items[0]['owners'][0]['country']
# Out:
# 'Taiwan Region'

# %%
# views
result_items[0]['stats']['views']
# Out:
# 2142

# %%
# appreciations
result_items[0]['stats']['appreciations']
# Out:
# 251

# %%
# comment
result_items[0]['stats']['comments']
# Out:
# 3

# %%
# url
result_items[0]['url']
# Out:
# 'https://www.behance.net/gallery/122475263/DOHER-StudioFish-Migration'

# %% [markdown]
# #### Step 7 - Put everything together - Loop through results and append data inside a list

# %%
name = []
first_name = []
last_name = []
user_name = []
country = []
views = []
appreciations = []
comments = []
url = []

for result in result_items:
    
    # name
    name.append(result['name'])
    
    # first name
    first_name.append(result['owners'][0]['first_name'])
    
    # last name
    last_name.append(result['owners'][0]['last_name'])
    
    # user name
    user_name.append(result['owners'][0]['username'])
    
    #country
    country.append(result['owners'][0]['country'])
    
    # views
    views.append(result['stats']['views'])
    
    # appreciations
    appreciations.append(result['stats']['appreciations'])
    
    # comments
    comments.append(result['stats']['comments'])
    
    # url
    url.append(result['url'])

# %% [markdown]
# #### Step 8 - Pandas Dataframe - Single Page

# %%
df = pd.DataFrame({'name' : name, 'first_name':first_name, 'last_name':last_name, 'username':user_name,
                  'country':country, 'views' : views, 'appreciations' : appreciations, 'comments' : comments,
                  'url' : url})

# %%
df
# Out:
#                                                  name     first_name  \
# 0                         DOHER Studio｜Fish Migration           Hey!
# 1                             CGI - CIRQUA APARTMENTS  Ander Alencar
# 2                                     Villa La Siesta           Nour
# 3                                        AMS wangzhai             晓斌
# 4                                           NP MUSEUM      Alexander
# 5                             SOUND AND VISION ballet      Sebastian
# 6                                                  悟空           二三設計
# 7                                         MOME Campus          Zsolt
# 8     Ludwig Mies van der Rohe inspired house for BMW       J Konrad
# 9                      Fengqiao Experience Exhibition         Angelo
# 10                                       Casa da mata         Studio
# 11                                     Architecture I          Serge
# 12                 Phoenix International Media Center      Ekaterina
# ...

# %% [markdown]
# #### Step 9 - Scraping Multiple Pages (here: 10 pages to get 480 results)

# %%
headers = {
    'authority': 'www.behance.net',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^94^\\^, ^\\^Google',
    'x-newrelic-id': 'VgUFVldbGwsFU1BRDwUBVw==',
    'x-bcp': '9f68537b-3d41-4309-992b-2a16b9e83674',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4590.0 Safari/537.36',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.behance.net/search/projects?field=architecture',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'gki=^%^7B^%^22db_semaphore^%^22^%^3Afalse^%^2C^%^22native_lazy_loading^%^22^%^3Afalse^%^2C^%^22feature_hire_me_cta^%^22^%^3Afalse^%^2C^%^22search_recommended_images_with_field_factor^%^22^%^3Afalse^%^2C^%^22feature_stock_rail^%^22^%^3Afalse^%^2C^%^22feature_updated_profile_checklist^%^22^%^3Afalse^%^7D; OptanonAlertBoxClosed=2021-08-02T06:04:21.127Z; feds_privacy_consent=^{^\\^hasUserProvidedConsent^\\^:true,^\\^userHasCustomConsent^\\^:false^}; sign_up_prompt=true; OptanonChoice=1; gk_suid=67106599; bcp=9f68537b-3d41-4309-992b-2a16b9e83674; AMCVS_9E1005A551ED61CA0A490D45^%^40AdobeOrg=1; AMCV_9E1005A551ED61CA0A490D45^%^40AdobeOrg=870038026^%^7CMCMID^%^7C36890020453938104313310156140129842450^%^7CMCAAMLH-1628607112^%^7C6^%^7CMCAAMB-1628607112^%^7CRKhpRz8krg2tLO6pguXWp5olkAcUniQYPHaMWWgdJ3xzPWQmdj0y^%^7CMCOPTOUT-1628009512s^%^7CNONE^%^7CMCAID^%^7CNONE^%^7CMCCIDH^%^7C-2144737571^%^7CvVersion^%^7C5.0.0; s_cc=true; gpv=behance.net:search:projects; s_sq=^%^5B^%^5BB^%^5D^%^5D; s_ppv=^[^%^22www.behance.net/^%^22^%^2C100^%^2C0^%^2C38350.80078125^%^2C558^%^2C754^%^2C1536^%^2C864^%^2C1.25^%^2C^%^22L^%^22^]; ilo0=true; OptanonConsent=isIABGlobal=false&datestamp=Tue+Aug+03+2021+17^%^3A44^%^3A38+GMT^%^2B0200+(Central+European+Summer+Time)&version=6.9.0&consentId=a7d2e804-5724-47c2-9e08-00c34472ff73&interactionCount=3&landingPath=NotLandingPage&groups=C0001^%^3A1^%^2CC0002^%^3A1^%^2CC0003^%^3A1^%^2CC0004^%^3A1&hosts=H111^%^3A1^%^2CH363^%^3A1^%^2CH364^%^3A1^%^2CH115^%^3A1^%^2CH117^%^3A1^%^2CH118^%^3A1^%^2CH119^%^3A1^%^2CH6^%^3A1^%^2CH122^%^3A1^%^2CH123^%^3A1^%^2CH127^%^3A1^%^2CH116^%^3A1^%^2CH4^%^3A1^%^2CH5^%^3A1^%^2CH120^%^3A1^%^2CH74^%^3A1^%^2CH76^%^3A1^%^2CH113^%^3A1^%^2CH320^%^3A1^%^2CH68^%^3A1^%^2CH88^%^3A1^%^2CH13^%^3A1^%^2CH37^%^3A1^%^2CH16^%^3A1^%^2CH67^%^3A1^%^2CH22^%^3A1^%^2CH93^%^3A1^%^2CH50^%^3A1^%^2CH124^%^3A1^%^2CH125^%^3A1^%^2CH126^%^3A1^%^2CH77^%^3A1^%^2CH35^%^3A1&geolocation=DE^%^3BHH&AwaitingReconsent=false',
}

name = []
first_name = []
last_name = []
user_name = []
country = []
views = []
appreciations = []
comments = []
url = []

# scrape 10 pages

for i in range(0,480,48):

    params = (
        ('content', 'projects'),
        ('field', 'architecture'),
        ('ordinal', str(i)),
    )

    # response
    response = requests.get('https://www.behance.net/search', headers=headers, params=params)
    
    # json object
    results_json = response.json()
    
    # list of results
    result_items = results_json['search']['content']['projects']
    
    for result in result_items:
    
        # name
        name.append(result['name'])

        # first name
        first_name.append(result['owners'][0]['first_name'])

        # last name
        last_name.append(result['owners'][0]['last_name'])

        # user name
        user_name.append(result['owners'][0]['username'])

        #country
        country.append(result['owners'][0]['country'])

        # views
        views.append(result['stats']['views'])

        # appreciations
        appreciations.append(result['stats']['appreciations'])

        # comments
        comments.append(result['stats']['comments'])

        # url
        url.append(result['url'])

# %%
df = pd.DataFrame({'name' : name, 'first_name':first_name, 'last_name':last_name, 'username':user_name,
                  'country':country, 'views' : views, 'appreciations' : appreciations, 'comments' : comments,
                  'url' : url})

# %%
df
# Out:
#                             name     first_name   last_name          username  \
# 0    DOHER Studio｜Fish Migration           Hey!      Cheese         heycheese
# 1        CGI - CIRQUA APARTMENTS  Ander Alencar   Oficina3d      anderalencar
# 2                Villa La Siesta           Nour    El Refai       nourelrefai
# 3                   AMS wangzhai             晓斌           吕         charleslv
# 4                      NP MUSEUM      Alexander      Velgan   aleksandrvelgan
# ..                           ...            ...         ...               ...
# 475     Student Hostel in Warsaw           PEAK      studio        peakstudio
# 476                         NORD           York  ARCHITECTS    yorkarchitc5e1
# 477        THAD dongjiliangxiang             晓斌           吕         charleslv
# 478             STV Channel ID's         Rudnev         pro         rudnevpro
# 479                  HOUSE № 212         Łukasz  Brzozowski  lukaszbrzozowski
#
# ...

# %% [markdown]
# #### Step 10 - Store Results in Excel

# %%
df.to_excel('pictures_multiple_pages.xlsx', index=False)
